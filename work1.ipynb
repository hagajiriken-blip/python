# %%
import numpy as np

# %%
a=np.array([(100,100,100),(100,100,199)])
print (a)

a.reshape(1,2)
print (a)
# Out:
# [[100 100 100]
#  [100 100 199]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 a=np.array([(100,100,100),(100,100,199)])
#       2 print (a)
# ----> 4 a.reshape(1,2)
#       5 print (a)
#
# ValueError: cannot reshape array of size 6 into shape (1,2)
